# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 14.0 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -e .
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 46708, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 46708 (delta 137), reused 152 (delta 93), pack-reused 46493 (from 1)
# Receiving objects: 100% (46708/46708), 38.49 MiB | 12.84 MiB/s, done.
# Resolving deltas: 100% (34813/34813), done.
# /content/ultralytics
# Obtaining file:///content/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.36-0.editable-py3-none-any.whl size=22677 sha256=47ab89aad5c8900b3524a26699c8b355e8ca5e6dd0938c31fa5528f74069f6c0
# ...

# %%
# !yolo task=detect \
mode=predict \
model=yolov8n-cls.pt \
conf=0.25 \
source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.31M/5.31M [00:00<00:00, 298MB/s]
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 62.0MB/s]
# ...
# 100% 755k/755k [00:00<00:00, 102MB/s]
# image 1/1 /content/ultralytics/dog.jpeg: 224x224 seat_belt 0.28, Walker_hound 0.24, beagle 0.15, basset 0.11, Labrador_retriever 0.04, 3.0ms
# Speed: 46.8ms preprocess, 3.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')
model.predict(
   source='https://media.roboflow.com/notebooks/examples/dog.jpeg',
   conf=0.25
)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/ultralytics/dog.jpeg: 224x224 seat_belt 0.28, Walker_hound 0.24, beagle 0.15, basset 0.11, Labrador_retriever 0.04, 3.0ms
# Speed: 11.6ms preprocess, 3.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cryJY7hrR0kI5fRmFTtD")
project = rf.workspace("tea-plant").project("tea-grading-ql1tl")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tea-grading-2 in yolov8:: 100%|██████████| 2416/2416 [00:00<00:00, 7538.47it/s]

# %%
# !yolo task=detect \
mode=train \
model=yolov8n-cls.pt \
data={dataset.location}/data.yaml \
epochs=100 \
imgsz=640
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(dataset.location)
# Out:
# /content/ultralytics/Edited-Real-Ai-1

# %%
# !ls /content/ultralytics/Edited-Real-Ai-1
# Out:
# data.yaml  data.yaml.zip  README.dataset.txt  README.roboflow.txt  test  train	valid

# %%
# !cat /content/ultralytics/Edited-Real-Ai-1/data.yaml
# Out:
# names:
# - Ai human 2
# - Edited images
# - Real human 2
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: edited-real-ai
#   url: https://universe.roboflow.com/tea-plant/edited-real-ai/dataset/1
#   version: 1
#   workspace: tea-plant
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !yolo task=detect \
mode=train \
model=yolov8n-cls.pt \
data= /content/ultralytics/Edited-Real-Ai-1/data.yaml \
epochs=15 \
imgsz=640
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics 8.3.36 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
